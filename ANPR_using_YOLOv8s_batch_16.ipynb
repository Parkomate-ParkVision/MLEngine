# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 14.4 MB/s eta 0:00:00
# ...

# %%
# !mkdir training_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ei8PuWM4xUIUR0iUfhic")
project = rf.workspace("trail-4zoer").project("license-plates-us-eu-ykkqr")
dataset = project.version(1).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 24.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 21.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
# ...

# %%
import os

file_list = os.listdir("/content/License-Plates-1/train/images")

# %%
len(file_list)
# Out:
# 735

# %%
! yolo task=detect \
mode=train \
model="/content/drive/MyDrive/BE Project/Data/YOLOv8/yolov8s.pt" \
data="/content/License-Plates-1/data.yaml" \
batch=16 \
epochs=70 \
imgsz=640
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect \
mode=val \
model=/content/runs/detect/train2/weights/best.pt \
data=/content/License-Plates-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/License-Plates-1/valid/labels.cache... 70 images, 0 backgrounds, 0 corrupt: 100% 70/70 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5/5 [00:04<00:00,  1.18it/s]
#                    all         70        218      0.883      0.794      0.874      0.694
#          license-plate         70         84      0.916      0.869      0.944      0.724
#                vehicle         70        134       0.85      0.718      0.803      0.665
# Speed: 4.6ms preprocess, 20.3ms inference, 0.0ms loss, 3.8ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect \
mode=predict \
model=/content/runs/detect/train2/weights/best.pt \
conf=0.25 \
source=/content/License-Plates-1/test/images
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/35 /content/License-Plates-1/test/images/b15d6c0bdf90226d_jpg.rf.9030bd5d82e439f1e8c9861358ad6f32.jpg: 640x640 1 license-plate, 1 vehicle, 16.3ms
# image 2/35 /content/License-Plates-1/test/images/b193070a9c45b5ab_jpg.rf.fd51c951795f2ca36b8fcad7fc5473eb.jpg: 640x640 1 license-plate, 2 vehicles, 16.3ms
# image 3/35 /content/License-Plates-1/test/images/b1a50a3824887ee2_jpg.rf.bcd7f6eb2562b23c8762778dae9ee6bc.jpg: 640x640 1 license-plate, 3 vehicles, 16.2ms
# image 4/35 /content/License-Plates-1/test/images/b25d7d2cb7abf86b_jpg.rf.d130afda33bf6f855d150729cdb42b80.jpg: 640x640 2 license-plates, 1 vehicle, 16.2ms
# image 5/35 /content/License-Plates-1/test/images/b32671b7cc279583_jpg.rf.f9955109375beade1e43400309f2c331.jpg: 640x640 1 license-plate, 2 vehicles, 16.2ms
# ...

# %%
import os
import shutil

source_dir = '/content/runs'
dest_dir = '/content/drive/MyDrive/BE Project/Data/YOLOv8/Trained Model'

if os.path.exists(dest_dir):
        shutil.rmtree(dest_dir)
        shutil.copytree(source_dir, dest_dir)

# %%
# !yolo task=detect \
mode=predict \
model=/content/runs/detect/train/weights/best.pt \
conf=0.25 \
source=/content/cover_3.jpeg
# Out:
# Ultralytics YOLOv8.0.195 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/cover_3.jpeg: 480x640 1 license-plate, 5 vehicles, 106.1ms
# Speed: 3.4ms preprocess, 106.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
