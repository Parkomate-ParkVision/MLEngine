# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/sovit-123/vision_transformers.git
# Out:
# Cloning into 'vision_transformers'...
# remote: Enumerating objects: 695, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 695 (delta 35), reused 44 (delta 25), pack-reused 591
# Receiving objects: 100% (695/695), 25.15 MiB | 15.79 MiB/s, done.
# Resolving deltas: 100% (402/402), done.

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...

# %%
# !pip install -r /content/vision_transformers/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 19.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.2/805.2 kB 53.0 MB/s eta 0:00:00
# ...

# %%
# !pip install vision_transformers
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for vision_transformers: filename=vision_transformers-0.1.1.0-py3-none-any.whl size=48414 sha256=c017b8678ac3c95266a4aeaee086e88b0dc7ce5b5a6c0111952437ad7aa28e30
#   Stored in directory: /root/.cache/pip/wheels/02/f4/94/0a5c8d2a4fcb6aa4c590906ffd3d52dc8edbe94262ecaa7dae
# Successfully built vision_transformers
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ei8PuWM4xUIUR0iUfhic")
project = rf.workspace("trail-4zoer").project("license-plates-us-eu-ykkqr")
dataset = project.version(1).download("voc")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 21.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 12.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 9.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
#       Successfully uninstalled opencv-python-headless-4.8.1.78
# ...

# %%
# !python /content/vision_transformers/tools/train_detector.py --epochs 50 --batch 16 --data /content/license_data.yaml --model detr_resnet50 --name detr_resnet50
# Out:
# Checking images and labels...
# 100% 735/735 [00:00<00:00, 115917.03it/s]
# Checking images and labels...
# 100% 70/70 [00:00<00:00, 292431.55it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Using cache found in /root/.cache/torch/hub/facebookresearch_detr_main
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...

# %%
# !python /content/vision_transformers/tools/eval.py --model detr_resnet50 --weights /content/runs/training/detr_resnet50/best_model.pth --data /content/license_data.yaml --imgsz 640
# Out:
# Using cache found in /root/.cache/torch/hub/facebookresearch_detr_main
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Checking images and labels...
# 100% 70/70 [00:00<00:00, 208671.84it/s]
# ...

# %%
# !python /content/vision_transformers/tools/inference_image_detect.py --weights /content/runs/training/detr_resnet50/best_model.pth --input "/content/License-Plates-1/test"
# Out:
# Using cache found in /root/.cache/torch/hub/facebookresearch_detr_main
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...
# Layer (type (var_name))                                                Output Shape              Param #
# ...
# DETRModel (DETRModel)                                                  [1, 100, 4]               --
# ...

# %%
import os
import shutil
src="/content/runs"
des="/content/drive/MyDrive/BE Project/Data/ViT DETR Trained Model"
if os.path.exists(des):
        shutil.rmtree(des)
        shutil.copytree(src, des)
