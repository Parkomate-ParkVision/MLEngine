# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/naseemap47/YOLO-NAS.git
# %cd YOLO-NAS
# !pip install -r requirements.txt
# Out:
# fatal: destination path 'YOLO-NAS' already exists and is not an empty directory.
# /content/YOLO-NAS
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ei8PuWM4xUIUR0iUfhic")
project = rf.workspace("trail-4zoer").project("license-plates-us-eu-ykkqr")
dataset = project.version(1).download("coco")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format coco in progress : 85.0%
# Version export complete for coco format
# ...
# Extracting Dataset Version Zip to License-Plates-1 in coco:: 100%|██████████| 847/847 [00:00<00:00, 6431.22it/s]

# %%
# %cd YOLO-NAS/
# %ls
# !rm -rf "/content/YOLO-NAS/License-Plates-1"

# %%
# !python3 train.py --data /content/YOLO-NAS/License-Plates-1/data.yaml --batch 16 --epoch 20 --model yolo_nas_m --size 640
# Out:
# The console stream is logged into /root/sg_logs/console.log
# [2023-10-30 03:17:38] INFO - crash_tips_setup.py - Crash tips is enabled. You can set your environment variable to CRASH_HANDLER=FALSE to disable it
# 2023-10-30 03:17:39.764328: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-30 03:17:39.764386: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-30 03:17:39.764425: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python3 inference.py --num 3 --model yolo_nas_m --weight "/content/YOLO-NAS/runs/train3/ckpt_best.pth" --source "/content/YOLO-NAS/License-Plates-1/test/b1a50a3824887ee2_jpg.rf.bcd7f6eb2562b23c8762778dae9ee6bc.jpg" --conf 0.5 --save
# Out:
# The console stream is logged into /root/sg_logs/console.log
# [2023-10-30 04:04:17] INFO - crash_tips_setup.py - Crash tips is enabled. You can set your environment variable to CRASH_HANDLER=FALSE to disable it
# 2023-10-30 04:04:19.294752: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-30 04:04:19.294819: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-30 04:04:19.294868: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import os
import shutil
src="/content/YOLO-NAS/runs"
des="/content/drive/MyDrive/BE Project/Data/YOLO-NAS Trained Model"
if os.path.exists(des):
        shutil.rmtree(des)
        shutil.copytree(src, des)
