# %%
# !pip install ultralytics

# %%
# !mkdir training_data
# Out:
# mkdir: cannot create directory ‘training_data’: File exists

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ei8PuWM4xUIUR0iUfhic")
project = rf.workspace("yolo-trials").project("vehicle-detection-eckrb")
dataset = project.version(4).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 14.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 12.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 9.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
# ...

# %%
import os

file_list = os.listdir("/content/Vehicle-detection-4/train/images")

# %%
len(file_list)
# Out:
# 4370

# %%
! yolo task=detect \
mode=train \
model="/content/drive/MyDrive/BE Project/Data/YOLOv8/yolov8s.pt" \
data="/content/Vehicle-detection-4/data.yaml" \
batch=64 \
epochs=30 \
imgsz=320
# Out:
# Ultralytics YOLOv8.1.11 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect \
mode=val \
model=/content/runs/detect/train5/weights/best.pt \
data=/content/Vehicle-detection-4/data.yaml
# Out:
# Ultralytics YOLOv8.1.11 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11131389 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /content/Vehicle-detection-4/valid/labels.cache... 1233 images, 0 backgrounds, 0 corrupt: 100% 1233/1233 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 78/78 [00:12<00:00,  6.26it/s]
#                    all       1233       1233      0.872       0.89      0.936      0.931
#              Ambulance       1233         22      0.807      0.864      0.923      0.915
#                   Auto       1233          2          1      0.876      0.995      0.995
#                Bicycle       1233         14      0.829      0.929      0.972      0.967
#                   Bike       1233        200      0.946      0.995      0.982      0.978
#                    Bus       1233         79      0.832      0.937      0.972      0.966
# ...

# %%
# !yolo task=detect \
mode=predict \
model=/content/runs/detect/train5/weights/best.pt \
conf=0.25 \
source=/content/Vehicle-detection-4/test/images
# Out:
# Ultralytics YOLOv8.1.11 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11131389 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/587 /content/Vehicle-detection-4/test/images/100Truck_jpg.rf.6d1fb54756da5451afc5d936cce31de8.jpg: 320x320 1 Truck, 9.6ms
# image 2/587 /content/Vehicle-detection-4/test/images/103car_jpg.rf.a7d51ea114c795df35e5cab28e56c85f.jpg: 320x320 1 Car, 8.2ms
# image 3/587 /content/Vehicle-detection-4/test/images/106Ambulance_jpg.rf.a7c62a2f4d83cfd74c1d7abd4f76b8b3.jpg: 320x320 1 Ambulance, 8.0ms
# image 4/587 /content/Vehicle-detection-4/test/images/107Truck_jpg.rf.19c20e850ae0e558acc150d2f9c4f2a8.jpg: 320x320 1 Truck, 8.0ms
# image 5/587 /content/Vehicle-detection-4/test/images/107_jpg.rf.4d3fee9c1a63b6f71882bedb0e05dbc3.jpg: 320x320 1 Car, 8.3ms
# image 6/587 /content/Vehicle-detection-4/test/images/107_jpg.rf.6d373b3f789bdc8a5b47ce7d7fab5eab.jpg: 320x320 1 Car, 8.0ms
# ...

# %%
# !rm -rf /content/runs/detect/train

# %%
import os
import shutil

source_dir = '/content/runs'
dest_dir = '/content/drive/MyDrive/BE Project/Data/Vehicle Detection using YOLOv8'

if os.path.exists(dest_dir):
        shutil.rmtree(dest_dir)
        shutil.copytree(source_dir, dest_dir)

# %%
# !yolo task=detect \
mode=predict \
model=/content/runs/detect/train5/weights/best.pt \
conf=0.25 \
source=/content/road.jpg
# Out:
# Ultralytics YOLOv8.1.11 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11131389 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/1 /content/road.jpg: 192x320 1 Bus, 1 Truck, 127.8ms
# Speed: 1.3ms preprocess, 127.8ms inference, 520.5ms postprocess per image at shape (1, 3, 192, 320)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
